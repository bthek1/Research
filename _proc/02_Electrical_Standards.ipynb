# %% [raw]
# ---
# description: Eletricial Standards
# output-file: electrical_standards.html
# skip_exec: true
# skip_showdoc: true
# title: Electrical Standards
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->
